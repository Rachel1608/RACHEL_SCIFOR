# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) Create and display a dataframe from a dictionary holding 2D or nd list values sales is name which stores values quarter wise sales.

# %%
sales = {
         "Q1":[100,120,140,160],
         "Q2":[200,220,240,260],
         "Q3":[300,320,340,360],
         "Q4":[400,420,440,460]}

df1 = pd.DataFrame(sales)
df1
# Out:
#     Q1   Q2   Q3   Q4
# 0  100  200  300  400
# 1  120  220  320  420
# 2  140  240  340  440
# 3  160  260  360  460

# %% [markdown]
# 2) Create a dataframe which displays the sales performance of 4 zonal offices your zone name should be the row labels, you can use seperate dictionary for each zone

# %%
sales_perf =[{"Zone":"Zone 1", "sales":10000},
             {"Zone":"Zone 2", "sales":15000},
             {"Zone":"Zone 3", "sales":20000},
             {"Zone":"Zone 4", "sales":30000}]
df2 = pd.DataFrame(sales_perf)
df2.set_index("Zone",inplace=True)
df2
# Out:
#         sales
# Zone
# Zone 1  10000
# Zone 2  15000
# Zone 3  20000
# Zone 4  30000

# %% [markdown]
# 4) Create a dataframe to store weight, age and name of 3 people by dictionary of list

# %%
info={"Name":["Ayush", "Riddhima", "Manik"],
      "Age":[22,25,30],
      "weight":[62,54,72]}

df3 = pd.DataFrame(info)
df3
# Out:
#        Name  Age  weight
# 0     Ayush   22      62
# 1  Riddhima   25      54
# 2     Manik   30      72
